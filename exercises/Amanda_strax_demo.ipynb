# %% [markdown]
# # Tutorial

# %% [markdown]
# Jelle, updated May 2019
#
# This notebook shows how to do basic analysis with straxen, much like `hax.minitrees`.

# %% [markdown]
# For reference, here are some jargon terms which we will introduce below:
#
#   * **Context**: Holds configuration on how to process
#   * **Dataframe** or **array**: table of related information produced by a plugin.
#   * **Plugin**: an algorithm that produces a dataframe
#   * **Data type**: specification of which columns are in a dataframe.
#   * **Data kind**: e.g. 'events' or 'peaks'. Dataframes of the same kind  have the same number of rows and can be merged.

# %%
import numpy as np
# This just ensures some comments in dataframes below display nicely
import pandas as pd
pd.options.display.max_colwidth = 100

# %% [markdown]
# ## Setting up

# %% [markdown]
# First we load a strax **context**, much like `hax.init()`. A strax context contains all information on *how* to process: where to read what files from, what plugins provide what data, etc.
#
# You can make a context yourselves using `strax.Context`, but straxen provides standardized contexts as well. Most future analyses will use such standardized contexts defined by analysis coordinators or straxen maintainers.
#
# Unlike `hax.init`, you can have multiple active contexts, e.g. to load analysis and MC data, or compare data processed with different settings (we will see examples of this below).

# %%
import straxen
st = straxen.contexts.demo()
#st2 = straxen.contexts.strax_workshop_dali()

# %% [markdown]
# ## Finding your data

# %% [markdown]
# Usually you'd be running on a XENON analysis facility with access to XENON data. This demo should run everywhere, so we'll have to download some data first:

# %%
straxen.download_test_data()

# %%
# !which python

#import straxen
straxen.__version__
# Out:
# /dali/lgrandi/strax/miniconda3/envs/strax/bin/python
# '0.2.0'

# %% [markdown]
# Suposse we want to make a cS1/cS2 plot. We have to figure out which type of **dataframes** to load. A specific type of dataframe is also called a **data type**. (in hax these were called minitrees)
#
# We can find this out automatically if we know (part of) the name of a field to load:

# %%
#st.search_field('*s1*')
st.search_field('*area*')
# Out:
# area is part of raw_records (provided by RecordsFromPax)
# s1_area is part of event_basics (provided by EventBasics)
# s1_area_fraction_top is part of event_basics (provided by EventBasics)
# s1_range_50p_area is part of event_basics (provided by EventBasics)
# s2_area is part of event_basics (provided by EventBasics)
# s2_area_fraction_top is part of event_basics (provided by EventBasics)
# s2_range_50p_area is part of event_basics (provided by EventBasics)
# s1_area is part of event_info (provided by EventInfo)
# s1_area_fraction_top is part of event_info (provided by EventInfo)
# s1_range_50p_area is part of event_info (provided by EventInfo)
# s2_area is part of event_info (provided by EventInfo)
# s2_area_fraction_top is part of event_info (provided by EventInfo)
# s2_range_50p_area is part of event_info (provided by EventInfo)
# area is part of peak_basics (provided by PeakBasics)
# max_pmt_area is part of peak_basics (provided by PeakBasics)
# range_50p_area is part of peak_basics (provided by PeakBasics)
# area_fraction_top is part of peak_basics (provided by PeakBasics)
# area is part of peaks (provided by Peaks)
# area_per_channel is part of peaks (provided by Peaks)
# area is part of records (provided by Records)

# %% [markdown]
# ??? where is the uncorrected s1 and s2? --> s1_area (?)

# %% [markdown]
# It seems we're after one of the data types called `event_info` or `corrected_areas`. In the current context, these are provided by **plugins** called EventInfo and CorrectedAreas, respectively (but this doesn't concern us yet).
#
# Let's see what else is in these data types:

# %%
#st.data_info('corrected_areas')
#st.data_info('peak_basics')
st.data_info('peaks')
# Out:
#               Field name        Data type  \
# 0                channel            int16
# 1                     dt            int16
# 2                   time            int64
# 3                 length            int32
# 4                   area          float32
# 5       area_per_channel  ('<i4', (248,))
# 6                 n_hits            int16
# 7                   data  ('<f4', (200,))
# 8                  width   ('<f4', (11,))
# 9      saturated_channel  ('<i2', (248,))
# 10  n_saturated_channels            int16
#
#                                                                                         Comment
# 0                                                                            Channel/PMT number
# 1                                                                         Time resolution in ns
# 2                                              Start time of the interval (ns since unix epoch)
# 3                                                             Length of the interval in samples
# 4                                                    Integral across channels in photoelectrons
# 5                                               Integral per channel in ADX x samples (not PE!)
# 6   Number of hits from which peak was constructed (currently zero if peak is split afterwards)
# 7                                                       Waveform data in PE/sample (not PE/ns!)
# 8                                             Peak widths in ns: range of central area fraction
# 9                                                                 Check if channel is saturated
# 10                                                           Total number of saturated channels

# %%
st.data_info('event_info')
# Out:
#                        Field name Data type  \
# 0                    event_number     int64
# 1                            time     int64
# 2                         endtime     int64
# 3                         n_peaks     int32
# 4                      drift_time     int64
# 5                        s1_index     int32
# 6                         s1_area   float32
# 7            s1_area_fraction_top   float32
# 8               s1_range_50p_area   float32
# 9                  s1_n_competing     int32
# 10                       s2_index     int32
# 11                        s2_area   float32
# 12           s2_area_fraction_top   float32
# 13              s2_range_50p_area   float32
# 14                 s2_n_competing     int32
# 15                           x_s2   float32
# 16                           y_s2   float32
# 17               s2_largest_other   float32
# 18               s1_largest_other   float32
# 19  alt_s1_interaction_drift_time   float32
# 20                              x   float32
# 21                              y   float32
# 22                              z   float32
# 23                              r   float32
# 24                        z_naive   float32
# 25                        r_naive   float32
# 26  r_field_distortion_correction   float32
# 27                          theta   float32
# 28                            cs1   float32
# 29                            cs2   float32
# 30                        e_light   float32
# 31                       e_charge   float32
# 32                          e_ces   float32
#
#                                                              Comment
# 0                                       Event number in this dataset
# 1                        Event start time in ns since the unix epoch
# 2                          Event end time in ns since the unix epoch
# 3                                       Number of peaks in the event
# 4                            Drift time between main S1 and S2 in ns
# 5                                                 Main S1 peak index
# 6                                     Main S1 area (PE), uncorrected
# 7                                          Main S1 area fraction top
# 8                                       Main S1 width (ns, 50% area)
# 9                                  Main S1 number of competing peaks
# 10                                                Main S2 peak index
# 11                                    Main S2 area (PE), uncorrected
# 12                                         Main S2 area fraction top
# 13                                      Main S2 width (ns, 50% area)
# 14                                 Main S2 number of competing peaks
# 15                Main S2 reconstructed X position (cm), uncorrected
# 16                Main S2 reconstructed Y position (cm), uncorrected
# 17                  Largest other S2 area (PE) in event, uncorrected
# 18                  Largest other S1 area (PE) in event, uncorrected
# 19                                    Drift time with alternative s1
# 20           Interaction x-position, field-distortion corrected (cm)
# 21           Interaction y-position, field-distortion corrected (cm)
# 22           Interaction z-position, field-distortion corrected (cm)
# 23      Interaction radial position, field-distortion corrected (cm)
# 24        Interaction z-position using mean drift velocity only (cm)
# 25  Interaction r-position using observed S2 positions directly (cm)
# 26             Correction added to r_naive for field distortion (cm)
# 27                            Interaction angular position (radians)
# 28                                            Corrected S1 area (PE)
# 29                                            Corrected S2 area (PE)
# 30                                      Energy in light signal (keV)
# 31                                     Energy in charge signal (keV)
# 32                                          Energy estimate (keV_ee)

# %% [markdown]
# As you can see, `event_info` has a lot more information; let's load that one. You can see from the documentation (TODO link) that `event_info`'s job is to merge the info from `corrected_areas` and other things.

# %% [markdown]
# ## Loading data

# %% [markdown]
# Next, you'll want to select a run. The `select_runs` function will return a dataframe with all available runs; there is a separate tutorial on more advanced use of this. In this demo context, we only have high-level data for the run `180215_1029` available (and low-level data for another):

# %%
st.select_runs()
# Out:
# Checking data availability: 100%|██████████| 5/5 [00:00<00:00, 61.81it/s]
#   mode         name      number tags  event_info_available  events_available  \
# 0       180215_1029  1802151029                       True              True
# 1       180423_1021  1804231021                      False             False
#
#    records_available  raw_records_available  peaks_available
# 0              False                  False             True
# 1              False                   True            False

# %%
st.show_config()
# Out:
#                option default  \
# 0   storage_converter   False
# 1           fuzzy_for      ()
# 2   fuzzy_for_options      ()
# 3    allow_incomplete   False
# 4       allow_rechunk    True
# 5  allow_multiprocess   False
# 6           allow_shm   False
# 7  forbid_creation_of      ()
# 8    store_run_fields      ()
# 9     check_available      ()
#
#                                                                                    current  \
# 0                                                                                    False
# 1                                                                                       ()
# 2                                                                                       ()
# 3                                                                                    False
# 4                                                                                     True
# 5                                                                                    False
# 6                                                                                    False
# 7                                                                           (raw_records,)
# 8  (name, number, reader.ini.name, tags.name, start, end, trigger.events_built, tags.name)
# 9                                        (raw_records, records, peaks, events, event_info)
#
#   applies_to  \
# 0    Context
# 1    Context
# 2    Context
# 3    Context
# 4    Context
# 5    Context
# 6    Context
# 7    Context
# 8    Context
# 9    Context
#
#                                                                                                   help
# 0     If True, save data that is loaded from one frontend through all willing other storage frontends.
# 1  Tuple of plugin names for which no checks for version, providing plugin, and config will be perf...
# 2                 Tuple of config options for which no checks will be performed when looking for data.
# 3                        Allow loading of incompletely written data, if the storage systems support it
# 4                                                             Allow rechunking of data during writing.
# 5                                        Allow multiprocessing.If False, will use multithreading only.
# 6                                                Allow use of /dev/shm for interprocess communication.
# 7  If any of the following datatypes is requested to be created, throw an error instead. Useful to ...
# 8                                               Tuple of run document fields to store during scan_run.
# 9                                        Tuple of data types to scan availability for during scan_run.

# %% [markdown]
# So lets' take that 180215_1029.
#
# To actually load data, you use `get_df` to get a pandas DataFrame, or `get_array` to get a numpy (structured) array. Let's go with pandas for now:

# %%
run_id = '180215_1029'
df = st.get_df(run_id, 'event_info')
df1 = st.get_df(run_id, 'peak_basics')

# %% [markdown]
# The first time you run this, it will take a moment: it has to actually process the data somewhat. We didn't ship highest-level demo data with straxen: that would mean we'd have to constantly update the test data when the algorithms change.
#
# Just like hax.minitrees.load, we got a dataframe back. You can specify a list of runid's instead of one run, and get the concatenated result back.
#
# Though it's not related to strax, let's make a quick plot of the events we just loaded:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def event_plot(df):
    plt.scatter(df.cs1, df.cs2,
                c=df.s1_area_fraction_top,
                vmin=0, vmax=0.3, 
                s=10,
                cmap=plt.cm.jet,
                marker='.', edgecolors='none')
    plt.colorbar(label="S1 area fraction top", extend='max')
    plt.xlabel('cS1 (PE)')
    plt.ylabel('cS2 (PE)')
    plt.xscale('symlog')
    plt.yscale('log')
    plt.ylim(1e2, 1e7)
    
event_plot(df)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(df1.area,bins=np.linspace(0,200,100))
plt.xlabel('areas (PE)')
#plt.ylabel('cS2 (PE)')
#plt.xscale('symlog')
plt.yscale('log')
#plt.ylim(1e2, 1e7)

# %% [markdown]
# Can you guess what kind of data this is? --> this is background data

# %% [markdown]
# ## Waveform analysis

# %% [markdown]
# The *peaks* data type contains the sum waveform information:

# %%
st.data_info('peaks')
# Out:
#               Field name        Data type  \
# 0                channel            int16
# 1                     dt            int16
# 2                   time            int64
# 3                 length            int32
# 4                   area          float32
# 5       area_per_channel  ('<i4', (248,))
# 6                 n_hits            int16
# 7                   data  ('<f4', (200,))
# 8                  width   ('<f4', (11,))
# 9      saturated_channel  ('<i2', (248,))
# 10  n_saturated_channels            int16
#
#                                                                                         Comment
# 0                                                                            Channel/PMT number
# 1                                                                         Time resolution in ns
# 2                                              Start time of the interval (ns since unix epoch)
# 3                                                             Length of the interval in samples
# 4                                                    Integral across channels in photoelectrons
# 5                                               Integral per channel in ADX x samples (not PE!)
# 6   Number of hits from which peak was constructed (currently zero if peak is split afterwards)
# 7                                                       Waveform data in PE/sample (not PE/ns!)
# 8                                             Peak widths in ns: range of central area fraction
# 9                                                                 Check if channel is saturated
# 10                                                           Total number of saturated channels

# %% [markdown]
# Notice the compound data types of the `data`, `width` and `saturated_channel` fields. Pandas does not support such types (well, it sort of does, but the resulting dataframes are quite inefficient), so we have to load this as a numpy array:

# %%
peaks = st.get_array(run_id, 'peaks')
type(peaks), peaks.dtype.names
# Out:
# (numpy.ndarray,
#  ('channel',
#   'dt',
#   'time',
#   'length',
#   'area',
#   'area_per_channel',
#   'n_hits',
#   'data',
#   'width',
#   'saturated_channel',
#   'n_saturated_channels'))

# %% [markdown]
# Now we can plot peak waveforms:

# %%
def plot_peak(p, t0=None, **kwargs):
    n = p['length']
    if t0 is None:
        t0 = p['time']
    plt.plot((p['time'] - t0) + np.arange(n) * p['dt'], 
             p['data'][:n] / p['dt'], 
             linestyle='steps-mid',
             **kwargs)
    plt.xlabel("Time (ns)")
    plt.ylabel("Sum waveform (PE / ns)")

plot_peak(peaks[55241])

# %%
def plot_peaks(main_i, n_before=0, n_after=0, label_threshold=0):
    for i in main_i + np.arange(-n_before, n_after + 1):
        p = peaks[i]
        label = None
        if p['area'] > label_threshold:
            label = '%.1f PE, %d ns dt' % (p['area'], p['dt'], )
        plot_peak(p,
                  t0=peaks[main_i]['time'],
                  label=label)
    plt.ylim(0, None)
    plt.legend(loc='best')
    plt.yscale('symlog')

plot_peaks(55240, n_after=0, n_before=2)

# %% [markdown]
# The abrupt termination of the S2 above is due to strax's data reduction.

# %% [markdown]
# ## Configuration changes

# %% [markdown]
# As you can see in the above plot, we have many events high up in the TPC at low S1. Perhaps you want to get rid of them by increasing the 'S1 coincidence requirement', i.e. the number of PMTs that must see something before a peak is labeled as S1. Then, of course, you want to load the event-level data again to see if it worked.

# %% [markdown]
# First, we need to see which configuration option we have to change. Strax plugins declare what configuration they take and what other plugins they depend on, so this is not very difficult. We just ask which options with `s1` in their name influence `event_basics`:

# %%
st.show_config('event_basics', 's1*')
# Out:
#               option  default    current           applies_to  \
# 0       s1_max_width      150  <OMITTED>  peak_classification
# 1  s1_min_n_channels        3  <OMITTED>  peak_classification
#
#                                                   help
# 0                           Maximum (IQR) width of S1s
# 1  Minimum number of PMTs that must contribute to a S1

# %%
st.show_config('peaks')
# Out:
#                option  \
# 0    diagnose_sorting
# 1          to_pe_file
# 2              filter
# 3        s2_tail_veto
# 4   save_outside_hits
# 5          to_pe_file
# 6         pax_raw_dir
# 7     stop_after_zips
# 8    events_per_chunk
# 9  samples_per_record
#
#                                                                                                default  \
# 0                                                                                                False
# 1                     https://raw.githubusercontent.com/XENONnT/strax_auxiliary_files/master/to_pe.npy
# 2  (0.012, -0.119, 2.435, -1.271, 0.357, -0.174, -0.0, -0.036, -0.028, -0.019, -0.025, -0.013, -0.0...
# 3                                                                                                 True
# 4                                                                                               (3, 3)
# 5                     https://raw.githubusercontent.com/XENONnT/strax_auxiliary_files/master/to_pe.npy
# 6                                                                                      /data/xenon/raw
# 7                                                                                                    0
# 8                                                                                                   50
# 9                                                                                                  110
#
#      current   applies_to  \
# 0  <OMITTED>        peaks
# 1  <OMITTED>        peaks
# 2  <OMITTED>      records
# 3  <OMITTED>      records
# 4  <OMITTED>      records
# 5  <OMITTED>      records
# 6  <OMITTED>  raw_records
# 7  <OMITTED>  raw_records
# 8  <OMITTED>  raw_records
# 9  <OMITTED>  raw_records
#
#                                                     help
# 0     Enable runtime checks for sorting and disjointness
# 1                   link to the to_pe conversion factors
# 2  Linear filter to apply to pulses, will be normalized.
# 3     Remove pulses after high-energy S2s (experimental)
# 4  Save (left, right) samples besides hits; cut the rest
# 5                   link to the to_pe conversion factors
# 6                        Directory with raw pax datasets
# 7             Convert only this many zip files. 0 = all.
# 8                    Number of events to yield per chunk
# 9                           Number of samples per record

# %%
st.show_config()
# Out:
#                option default  \
# 0   storage_converter   False
# 1           fuzzy_for      ()
# 2   fuzzy_for_options      ()
# 3    allow_incomplete   False
# 4       allow_rechunk    True
# 5  allow_multiprocess   False
# 6           allow_shm   False
# 7  forbid_creation_of      ()
# 8    store_run_fields      ()
# 9     check_available      ()
#
#                                                                                    current  \
# 0                                                                                    False
# 1                                                                                       ()
# 2                                                                                       ()
# 3                                                                                    False
# 4                                                                                     True
# 5                                                                                    False
# 6                                                                                    False
# 7                                                                           (raw_records,)
# 8  (name, number, reader.ini.name, tags.name, start, end, trigger.events_built, tags.name)
# 9                                        (raw_records, records, peaks, events, event_info)
#
#   applies_to  \
# 0    Context
# 1    Context
# 2    Context
# 3    Context
# 4    Context
# 5    Context
# 6    Context
# 7    Context
# 8    Context
# 9    Context
#
#                                                                                                   help
# 0     If True, save data that is loaded from one frontend through all willing other storage frontends.
# 1  Tuple of plugin names for which no checks for version, providing plugin, and config will be perf...
# 2                 Tuple of config options for which no checks will be performed when looking for data.
# 3                        Allow loading of incompletely written data, if the storage systems support it
# 4                                                             Allow rechunking of data during writing.
# 5                                        Allow multiprocessing.If False, will use multithreading only.
# 6                                                Allow use of /dev/shm for interprocess communication.
# 7  If any of the following datatypes is requested to be created, throw an error instead. Useful to ...
# 8                                               Tuple of run document fields to store during scan_run.
# 9                                        Tuple of data types to scan availability for during scan_run.

# %% [markdown]
# Looks like we're after the `s1_min_n_channels option`. Note this is not part of the `event_basics` data type, but of a data type called `peak_classification`. As you can see from the table, this option is not set in the current context, so the default value (3) is used.
#
# To try out a different option, just pass it to get_df:

# %%
df_2 = st.get_df(run_id, 'event_info',
                 config=dict(s1_min_n_channels=50))
event_plot(df_2)

# %% [markdown]
# Notice all the small S1 events are indeed gone now.
#
# Behind the scenes, this figured out which dataframes had to be remade: as it happens this time just `event_basics` and `peak_basics`. You will now have a new `event_basics_<somehash>` folder in `./custom_data` which contains the results, as well as a new `peak_basics_<somehash> folder`.

# %% [markdown]
# ### More on configuration changes

# %% [markdown]
# Changing configuration can be done in two other ways. We can change it permanently in the current context:
# ```python
# st.set_config(dict(s1_min_channels=50))
# ```
# Or we could make a new context, with this option set:
# ```python
# st_2 = st.new_context(config=dict(s1_min_channels=50))
# ```
# (feeding it to get_df just does the latter behind the scenes).

# %% [markdown]
# Strax protects you from typos in the configuration. Suppose we typed `s1_min_n_channelz` instead:

# %%
df_2 = st.get_df(run_id, 'event_info',
                 config=dict(s1_min_n_channelz=10))
event_plot(df_2)
# Out:
# /dali/lgrandi/strax/strax/strax/context.py:330: UserWarning: Option s1_min_n_channelz not taken by any registered plugin
#   warnings.warn(f"Option {k} not taken by any registered plugin")

# %% [markdown]
# The result of get_df is just the same as if the option wasn't set (just like in pax/hax), but you also get a warning about an unknown configuration option.
#
# By the way, you can use
# ```python
# import warnings
# warnings.filterwarnings("error")
# ```
# to ensure any warning raises an exception instead.

# %% [markdown]
# ## Customization: new plugins

# %% [markdown]
# To add or change processing algorithms, or to define new variables to use in cuts, you have to write new strax plugins. These are somewhat similar to hax's treemakers.
#
# Suppose you have a brilliant new idea for peak classification:

# %%
import strax
import numpy as np

class AdvancedExpertClassification(strax.Plugin):
    """Everything is an S1!"""
    
    # Name of the data type this plugin provides
    provides = 'peak_classification'
    
    # Data types this plugin requires. Note we don't specify
    # what plugins should produce them: maybe the default PeakBasics
    # has been replaced by another AdvancedExpertBlabla plugin?
    depends_on = ('peak_basics',)
    
    # Numpy datatype of the output 
    dtype = straxen.plugins.plugins.PeakClassification.dtype
    
    # Version of the plugin. Increment this if you change the algorithm.
    __version__ = '0.0.1'

    def compute(self, peaks):
        # Your code here.
        # This function will be called several times with 
        # 'peaks' a numpy array of the datatype 'peaks'.
        # Each time you'll see a small part of the run.
        
        # You have to return a numpy array of the dtype you declared above
        # or, which is often easier, a dictionary we can transform into it
        # (dict keys -> field names, values -> field values)
        return dict(type=np.ones(len(peaks)))

# %% [markdown]
# Notice the plugin provides 'peak_classification' and produces the same data type as PeakClassification plugin, which in this case is just:

# %%
AdvancedExpertClassification.dtype
# Out:
# [('type', numpy.int8, 'Classification of the peak.')]

# %% [markdown]
# To use it in place of PeakClassification, we only have to register it. Again, we can do so permanently using
# ```python
# st.register(AdvancedExpertClassification)
# ```
# or temporarily, by feeding the registration as an extra argument to `get_df`:

# %%
df = st.get_df(run_id, 'event_info',
               register=AdvancedExpertClassification)

# %%
df['s2_area'].max()
# Out:
# 0.0

# %% [markdown]
# As you can see, all events are now S1-only events, as expected. Maybe this is not the best alternative classification :-)
#
# This plugin was the most basic possible plugin. You'll also want to learn about `LoopPlugin`s and `OverlapWindowPlugin`s, but that's beyond the scope of this tutorial.

# %%
st.
# Out:
#   File "<ipython-input-229-9af791239598>", line 1
#     st.
#        ^
# SyntaxError: invalid syntax

# %%
st.data_info('peak_basics')

# %% [markdown]
# # Exercise 1:
# Make your own peak classification plugin. Try different variables, different settings, or define some new ones. See how your new classification changes the final result (the events). Perhaps you'd like to focus on one type of peak in particular, or can you find peaks besides S1s/S2s?

# %% [markdown]
# ## Original Code
#
# class PeakClassification(strax.Plugin):
#     __version__ = '0.0.1'
#     depends_on = ('peak_basics',)
#     dtype = [
#         ('type', np.int8, 'Classification of the peak.')]
#     parallel = True
#
#     def compute(self, peaks):
#         p = peaks
#         r = np.zeros(len(p), dtype=self.dtype)
#
#         is_s1 = p['n_channels'] >= self.config['s1_min_n_channels']
#         is_s1 &= p['range_50p_area'] < self.config['s1_max_width']
#         r['type'][is_s1] = 1
#
#         is_s2 = p['area'] > self.config['s2_min_area']
#         is_s2 &= p['range_50p_area'] > self.config['s2_min_width']
#         r['type'][is_s2] = 2
#
#         return r

# %%
st.search_field('type')

# %%
st.data_info('peaks')
# Out:
#               Field name        Data type  \
# 0                channel            int16
# 1                     dt            int16
# 2                   time            int64
# 3                 length            int32
# 4                   area          float32
# 5       area_per_channel  ('<i4', (248,))
# 6                 n_hits            int16
# 7                   data  ('<f4', (200,))
# 8                  width   ('<f4', (11,))
# 9      saturated_channel  ('<i2', (248,))
# 10  n_saturated_channels            int16
#
#                                                                                         Comment
# 0                                                                            Channel/PMT number
# 1                                                                         Time resolution in ns
# 2                                              Start time of the interval (ns since unix epoch)
# 3                                                             Length of the interval in samples
# 4                                                    Integral across channels in photoelectrons
# 5                                               Integral per channel in ADX x samples (not PE!)
# 6   Number of hits from which peak was constructed (currently zero if peak is split afterwards)
# 7                                                       Waveform data in PE/sample (not PE/ns!)
# 8                                             Peak widths in ns: range of central area fraction
# 9                                                                 Check if channel is saturated
# 10                                                           Total number of saturated channels

# %%
d = st.get_df(run_id, 'peak_classification')
d1 = d[d['type']==1]
#print (d1)

# %%
import strax
import numpy as np

class AmandasClassification(strax.Plugin):
    """Find lone hits and Single Electrons!"""
    
    # Name of the data type this plugin provides
    provides = 'peak_classification'
    
    # Data types this plugin requires. Note we don't specify
    # what plugins should produce them: maybe the default PeakBasics
    # has been replaced by another AdvancedExpertBlabla plugin?
    depends_on = ('peak_basics',)
    
    # Numpy datatype of the output 
    dtype = straxen.plugins.plugins.PeakClassification.dtype
    
    # Version of the plugin. Increment this if you change the algorithm.
    __version__ = '0.0.5'

    def compute(self, peaks):
        
        p = peaks
        r = np.zeros(len(p), dtype=self.dtype)
        
        #is_s1 = p['n_channels'] >= self.config['s1_min_n_channels']
        #is_s1 &= p['range_50p_area'] < self.config['s1_max_width']
        #r['type'][is_s1] = 1

        #is_s2 = p['area'] > self.config['s2_min_area']
        #is_s2 &= p['range_50p_area'] > self.config['s2_min_width']
        #r['type'][is_s2] = 2

        is_lh = p['n_channels'] == 1
        r['type'][is_lh] = 3
        
        is_se = p['area'] < 50
        is_se &= p['area'] > 10
        is_se &= p['range_50p_area'] > 1e2
        is_se &= p['range_50p_area'] < 4e2
        r['type'][is_se] = 4
        
        return r
        #return dict(type=np.ones(len(peaks)))

# %%
df4 = st.get_df(run_id, ['peak_basics','peak_classification'],
               register=AmandasClassification)
df4.head()

ar4 = st.get_array(run_id, 'peaks',
               register=AmandasClassification)

# %%
d1 = df4[df4.type==1]
d2 = df4[df4.type==2]
d3 = df4[df4.type==3]
d4 = df4[df4.type==4]

print (len(df4))
print (len(d1))
print (len(d2))
print (len(d3))
print (len(d4))
# Out:
# 64999
# 0
# 0
# 35692
# 9985

# %%
d4.head()
# Out:
#                    time              endtime       area  n_channels  max_pmt  \
# 75  1518690592150894900  1518690592150895650  10.046149           3       78
# 83  1518690592150913330  1518690592150914440  42.266979          23      138
# 87  1518690592163546250  1518690592163547040  18.759594          12       11
# 88  1518690592164390590  1518690592164391330  28.216263          12       45
# 89  1518690592164392080  1518690592164392890  34.085724          17       74
#
#     max_pmt_area  range_50p_area  area_fraction_top  length  dt  type
# 75           763      233.729294           0.815139      75  10     4
# 83           871      207.997559           0.571405     111  10     4
# 87           416      280.866394           0.854337      79  10     4
# 88          1299      293.621155           0.693180      74  10     4
# 89          1032      292.719604           0.700086      81  10     4

# %%
print (ar4['area'])
# Out:
# [1.058814  0.6404985 0.        ... 0.        1.3321481 0.       ]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

    
from multihist import Histdd
f = plt.figure(figsize=(12,8))
m2 = Histdd(d3.area,
            d3.max_pmt,
            bins=[np.linspace(0,50,100),np.linspace(0,250,250)])
m2.plot(cblabel = 'Count', log_scale = True, cmap = 'viridis')
plt.xlabel('area (PE)',fontsize=20)
plt.ylabel('PMT channel',fontsize=20)
plt.title('Lone Hits')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

    
from multihist import Histdd
f = plt.figure(figsize=(12,8))
m2 = Histdd(d4.area,
            d4.area_fraction_top,
            bins=[np.linspace(0,50,100),np.linspace(0,1,100)])
m2.plot(cblabel = 'Count', log_scale = True, cmap = 'viridis')
plt.xlabel('area (PE)',fontsize=20)
plt.ylabel('AFT',fontsize=20)
plt.title('Single Electrons')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

    
from multihist import Histdd
f = plt.figure(figsize=(12,8))
m2 = Histdd(d4.area,
            d4.range_50p_area,
            bins=[np.linspace(0,60,100),np.linspace(9e0,5e2,100)])
m2.plot(cblabel = 'Count', log_scale = True, cmap = 'viridis')
plt.xlabel('area (PE)',fontsize=20)
plt.ylabel('Width',fontsize=20)
plt.title('Single Electrons')
plt.show()

# %%
def plot_peak(p, t0=None, **kwargs):
    n = p['length']
    if t0 is None:
        t0 = p['time']
    plt.plot((p['time'] - t0) + np.arange(n) * p['dt'], 
             p['data'][:n] / p['dt'], 
             linestyle='steps-mid',
             **kwargs)
    plt.xlabel("Time (ns)")
    plt.ylabel("Sum waveform (PE / ns)")

plot_peak(ar4[5])

# %% [markdown]
# # Exercise 2
#
# Use background data to derive an electron lifetime. Focus on data extraction, e.g. of the alpha peaks, and data cleaning, not the fitting/uncertainties. Do you see good agreement with the value in the runs db?

# %%
import strax
st1 = straxen.contexts.strax_workshop_dali()

dsets = st1.select_runs(include_tags='sciencerun2_preliminary', 
                       exclude_tags='?fterNG',
                       available='raw_records', 
                       run_mode='background*')
dsets
# Out:
# Checking data availability: 100%|██████████| 5/5 [00:01<00:00,  1.97it/s]
#                          end                    mode         name  number  \
# 2  2018-02-15 10:30:55+00:00  background_triggerless  180215_1029   16854
# 3  2018-02-16 14:24:47+00:00  background_triggerless  180216_1324   16887
# 4  2018-02-16 15:55:09+00:00  background_triggerless  180216_1455   16889
# 5  2018-02-16 17:25:29+00:00  background_triggerless  180216_1625   16891
# 6  2018-02-17 00:57:19+00:00  background_triggerless  180216_2357   16901
# 7  2018-02-17 02:27:41+00:00  background_triggerless  180217_0127   16903
# 8  2018-02-17 03:58:03+00:00  background_triggerless  180217_0257   16905
# 9  2018-02-17 05:28:23+00:00  background_triggerless  180217_0428   16907
# 10 2018-02-17 06:28:35+00:00  background_triggerless  180217_0528   16908
# 11 2018-02-17 12:30:14+00:00  background_triggerless  180217_1130   16916
# 12 2018-02-17 16:03:31+00:00  background_triggerless  180217_1503   16921
# 13 2018-02-17 21:05:04+00:00  background_triggerless  180217_2004   16928
# 14 2018-02-18 03:36:51+00:00  background_triggerless  180218_0236   16937
# 15 2018-02-18 09:38:32+00:00  background_triggerless  180218_0838   16945
# 16 2018-02-18 12:39:17+00:00  background_triggerless  180218_1139   16949
# 17 2018-02-18 15:40:12+00:00  background_triggerless  180218_1439   16953
# 18 2018-02-18 17:10:34+00:00  background_triggerless  180218_1610   16955
# 19 2018-02-18 18:40:56+00:00  background_triggerless  180218_1740   16957
# 20 2018-02-18 21:41:37+00:00  background_triggerless  180218_2041   16961
# 21 2018-02-19 00:42:26+00:00  background_triggerless  180218_2342   16965
# 22 2018-02-19 06:43:57+00:00  background_triggerless  180219_0543   16973
# 23 2018-02-19 09:44:46+00:00  background_triggerless  180219_0844   16977
# 34 2018-02-19 16:04:31+00:00  background_triggerless  180219_1504   16994
# 35 2018-02-19 17:34:51+00:00  background_triggerless  180219_1634   16996
# 36 2018-02-20 14:40:09+00:00  background_triggerless  180220_1340   17024
# 37 2018-02-20 16:10:30+00:00  background_triggerless  180220_1510   17026
# 38 2018-02-20 17:40:52+00:00  background_triggerless  180220_1640   17028
# 39 2018-02-21 01:13:02+00:00  background_triggerless  180221_0012   17038
# 40 2018-02-21 04:14:03+00:00  background_triggerless  180221_0313   17042
# 41 2018-02-21 05:44:33+00:00  background_triggerless  180221_0444   17044
# 42 2018-02-21 07:45:07+00:00  background_triggerless  180221_0644   17047
#
#            reader.ini.name                     start  \
# 2   background_triggerless 2018-02-15 10:29:52+00:00
# 3   background_triggerless 2018-02-16 13:24:43+00:00
# 4   background_triggerless 2018-02-16 14:55:06+00:00
# 5   background_triggerless 2018-02-16 16:25:26+00:00
# 6   background_triggerless 2018-02-16 23:57:16+00:00
# 7   background_triggerless 2018-02-17 01:27:38+00:00
# 8   background_triggerless 2018-02-17 02:58:00+00:00
# 9   background_triggerless 2018-02-17 04:28:20+00:00
# 10  background_triggerless 2018-02-17 05:28:32+00:00
# 11  background_triggerless 2018-02-17 11:30:11+00:00
# 12  background_triggerless 2018-02-17 15:03:28+00:00
# 13  background_triggerless 2018-02-17 20:05:01+00:00
# 14  background_triggerless 2018-02-18 02:36:48+00:00
# 15  background_triggerless 2018-02-18 08:38:29+00:00
# 16  background_triggerless 2018-02-18 11:39:14+00:00
# 17  background_triggerless 2018-02-18 14:40:09+00:00
# 18  background_triggerless 2018-02-18 16:10:30+00:00
# 19  background_triggerless 2018-02-18 17:40:52+00:00
# 20  background_triggerless 2018-02-18 20:41:34+00:00
# 21  background_triggerless 2018-02-18 23:42:22+00:00
# 22  background_triggerless 2018-02-19 05:43:54+00:00
# 23  background_triggerless 2018-02-19 08:44:42+00:00
# 34  background_triggerless 2018-02-19 15:04:28+00:00
# 35  background_triggerless 2018-02-19 16:34:49+00:00
# 36  background_triggerless 2018-02-20 13:40:06+00:00
# 37  background_triggerless 2018-02-20 15:10:26+00:00
# 38  background_triggerless 2018-02-20 16:40:50+00:00
# 39  background_triggerless 2018-02-21 00:12:58+00:00
# 40  background_triggerless 2018-02-21 03:13:59+00:00
# 41  background_triggerless 2018-02-21 04:44:31+00:00
# 42  background_triggerless 2018-02-21 06:45:03+00:00
#
#                                                tags  trigger.events_built  \
# 2   _sciencerun2_candidate,_sciencerun2_preliminary                 858.0
# 3   _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 4   _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 5   _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 6   _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 7   _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 8   _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 9   _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 10  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 11  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 12  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 13  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 14  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 15  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 16  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 17  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 18  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 19  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 20  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 21  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 22  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 23  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 34  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 35  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 36  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 37  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 38  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 39  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 40  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 41  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
# 42  _sciencerun2_candidate,_sciencerun2_preliminary               36292.0
#
#     event_info_available  events_available  records_available  \
# 2                   True              True               True
# 3                   True              True               True
# 4                   True              True               True
# 5                   True              True               True
# 6                   True              True               True
# 7                   True              True               True
# 8                   True              True               True
# 9                   True              True               True
# 10                  True              True               True
# 11                  True              True               True
# 12                  True              True               True
# 13                  True              True               True
# 14                  True              True               True
# 15                  True              True               True
# 16                  True              True               True
# 17                  True              True               True
# 18                  True              True               True
# 19                  True              True               True
# 20                  True              True               True
# 21                  True              True               True
# 22                  True              True               True
# 23                  True              True               True
# 34                  True              True               True
# 35                  True              True               True
# 36                  True              True               True
# 37                  True              True               True
# 38                  True              True               True
# 39                  True              True               True
# 40                  True              True               True
# 41                  True              True               True
# 42                  True              True               True
#
#     raw_records_available  peaks_available
# 2                    True             True
# 3                    True             True
# 4                    True             True
# 5                    True             True
# 6                    True             True
# 7                    True             True
# 8                    True             True
# 9                    True             True
# 10                   True             True
# 11                   True             True
# 12                   True             True
# 13                   True             True
# 14                   True             True
# 15                   True             True
# 16                   True             True
# 17                   True             True
# 18                   True             True
# 19                   True             True
# 20                   True             True
# 21                   True             True
# 22                   True             True
# 23                   True             True
# 34                   True             True
# 35                   True             True
# 36                   True             True
# 37                   True             True
# 38                   True             True
# 39                   True             True
# 40                   True             True
# 41                   True             True
# 42                   True             True

# %%
run_id_2 = ['180216_1324','180218_0236','180221_0444']
data = st1.get_df(run_id_2, 'event_info')
# Out:
# Loading 3 runs: 3it [00:00, 14.64it/s]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def event_plot(df):
    plt.scatter(df.cs1, df.cs2,
                c=df.s1_area_fraction_top,
                vmin=0, vmax=0.3, 
                s=10,
                cmap=plt.cm.jet,
                marker='.', edgecolors='none')
    plt.colorbar(label="S1 area fraction top", extend='max')
    plt.xlabel('cS1 (PE)')
    plt.ylabel('cS2 (PE)')
    plt.xscale('symlog')
    plt.yscale('log')
    plt.ylim(1e2, 1e7)
    
event_plot(data)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

    
from multihist import Histdd
f = plt.figure(figsize=(12,8))
m2 = Histdd(data.cs1,
            data.cs2,
            bins=[np.linspace(0,1e5,1000),np.logspace(2,6,1000)])
            #bins=[np.linspace(2e4,3e5,100),np.linspace(1e2,2e5,100)])
            #bins=[100,100])
m2.plot(cblabel = 'Count', log_scale = True, cmap = 'viridis')
plt.xlabel('cS1 (PE)',fontsize=20)
plt.ylabel('cS2 (PE)',fontsize=20)
#plt.xscale('log')
plt.yscale('log')
#plt.xscale('symlog')


#plt.title('Single Electrons')
plt.show()
